# %%
import numpy as np
#data types in python


# integer
# Floating
# boolean 
# complexx numbers 
# string
# object

# %%
#complex number
arr1 = np.array([3 + 5j])
arr2 = np.array([2 + 3j])
print(arr1 + arr2)
print(arr1, arr1.dtype)
# Out:
# [5.+8.j]
# [3.+5.j] complex128
